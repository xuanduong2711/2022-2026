# %% [markdown]
# # Probability & Statistics questions:

# %% [markdown]
# #### 1. The probability of passing three candidates A, B, and C in one interview are 60%, 10%, nd 20% respectively. Find the probability of success of at least two (2 points)

# %% [markdown]
# Ta có:
# Gọi A là biến cố  thành công của người A
# Gọi B là biến cố  thành công của người B
# Gọi C là biến cố  thành công của người C
# Gọi X là biến cố ít nhất 2 người thành công
#
# P(X)= [ P(A).P(B).(1-P(C)) ] + [ P(A).P(C).(1-P(B)) ] + [ P(C).P(B).(1-P(A)) ] + P(A).P(B).P(C)\
#     = (0.6* 0.1* 0.8) + (0.6* 0.2* 0.9) + (0.2* 0.1* 0.4) + 0.6* 0.1* 0.2]\
#     = 0.176

# %% [markdown]
# #### 2. Nine cards are drawn from a deck of 52 cards. What is the probability that 5 cards are diamonds and 2 are hearts and 2 are kings? (2 points)

# %% [markdown]
# Không gian mẫu  là 52C9 \
# Xét  3 TH
# - TH1: Chỉ cần rút 7 lá thỏa đủ điểu kiện\
#     $P(A) = \frac{{13 \choose 5} \cdot {13 \choose 2} \cdot {24 \choose 2}}{{52 \choose 9}} \approx 0.00753$
# - TH2:  Chỉ cần 8 lá thỏa điều kiện\
#     $P(B) = \frac{ 2{13 \choose 5} \cdot {13 \choose 2} \cdot {3 \choose 1} \cdot {24 \choose 1}}{{52 \choose 9}} \approx 0.00393$
# - TH3:  Phải cần 9 lá thỏa điều kiện\
#     $P(C) = \frac{{13 \choose 5} \cdot {13 \choose 2} \cdot {2 \choose 2} }{{52 \choose 9}} \approx 0.000027$\
# Vậy xác suất khi rút 9 lá để thỏa điều kiện là 0.00753+0.00393+0.000027= 0.011487

# %% [markdown]
# #### 3. There are transactions from banks A, B, and C at your company. About 30% of the population comes from A, 20% from B, and 50% from C. Knowing that there is a chance of fraud in the transaction history. The percentages for banks A, B, and C are 3%, 5%, and 4%, respectively.

# %% [markdown]
# X là biến cố gian lận\
# => P(X)= P(A)* P(X|A) + P(B)* P(X|B) P(C)* P(X|C)= 0.3* 0.03 +0.2* 0.05 + 0.5* 0.04 = 0.039\
# P(A|X) = $ \frac{P(A) P(A|X)}{P(X)} = \frac{0.3* 0.03}{0.039} \approx $ 0.2308\
# P(B|X) = $ \frac{P(B) P(B|X)}{P(X)} = \frac{0.2* 0.05}{0.039} \approx $ 0.2564 \
# P(C) = 1- P(A|X) - P(B|X) = 0.5128\
# => C có tỉ lệ cao nhất

# %% [markdown]
# #### 4. Assume that the amount of transaction in Service X in your company follow the Normal distribution with mean µ. A random sample of 250 000 transactions yieldedan average amount of 𝑥 ̅= 525 000 VND, and the standard deviation of the 250000 transactions is found to be s = 28 340. A 90% confidence interval for µ is (Hint:The t critical value for 90% CI for Degrees of freedom = 24 is 1.711) (2 points)

# %% [markdown]
# n= 250 000\
# $\bar{x} = 525 000$\
# s= 28 340\
#
# Ta có:\
# Cl =90% => $\alpha$ = 0.1\
# n= 250 000 thì khoảng tin cậy cho phân phối Z cũng như phân phối T\
# $\epsilon$ = $t_{\alpha/2}$  $\frac{s}{\sqrt{n}} $ = 1.711* 56.68= 96.98\
# => KTC (90% ) là (524903.02 ; 525096.98 )

# %% [markdown]
# # Data & Coding:

# %% [markdown]
# ### Khởi tạo thư viện

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %% [markdown]
# ### Đọc dữ liệu, xem xét và thống kê data

# %%
df= pd.read_csv("/home/duongdz/OneDrive/2022-2026/Nam 3/Python cho KHDL/LAB/Lab_2/transaction_data.csv")
df
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 0        278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1        337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2        267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3        380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 4            -1        6143225  Mon Sep 10 11:58:00 IST 2018   1733592
# ...         ...            ...                           ...       ...
# 1083813  313131        6040298  Mon Jun 18 09:18:00 IST 2018    437976
# 1083814  295743        6387117  Sat Feb 16 09:14:00 IST 2019    484113
# 1083815      -1        6361817  Tue Feb 05 05:26:00 IST 2019    497595
# 1083816  324765        5945500  Fri Mar 23 06:26:00 IST 2018    470883
# 1083817  351645        6118145  Tue Aug 21 08:21:00 IST 2018    471849
#
#                            ItemDescription  NumberOfItemsPurchased  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1083818 entries, 0 to 1083817
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1083818 non-null  int64
#  1   TransactionId           1083818 non-null  int64
#  2   TransactionTime         1083818 non-null  object
#  3   ItemCode                1083818 non-null  int64
#  4   ItemDescription         1080910 non-null  object
#  5   NumberOfItemsPurchased  1083818 non-null  int64
#  6   CostPerItem             1083818 non-null  float64
#  7   Country                 1083818 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 66.2+ MB

# %%
df.describe()
# Out:
#              UserId  TransactionId      ItemCode  NumberOfItemsPurchased  \
# count  1.083818e+06   1.083818e+06  1.083818e+06            1.083818e+06
# mean   2.410162e+05   6.159417e+06  6.582687e+05            2.865675e+01
# std    1.423364e+05   1.476341e+05  4.526314e+05            6.542432e+02
# min   -1.000000e+00   5.900015e+06 -1.000000e+00           -2.429850e+05
# 25%    2.593920e+05   6.026856e+06  4.609080e+05            3.000000e+00
# 50%    3.020220e+05   6.166611e+06  4.752930e+05            9.000000e+00
# 75%    3.413550e+05   6.289569e+06  4.889430e+05            3.000000e+01
# max    3.840270e+05   6.397457e+06  1.894494e+06            2.429850e+05
#
#         CostPerItem
# count  1.083818e+06
# mean   9.498798e+00
# std    2.308139e+03
# min   -1.526564e+04
# 25%    1.730000e+00
# 50%    2.880000e+00
# 75%    5.700000e+00
# max    1.696285e+06

# %% [markdown]
# ### 1 Clean data and filter Outliers (Explain your ideas and ways how to find out Outliers and the ways to treat them)

# %%
df.isnull().sum()
# Out:
# UserId                       0
# TransactionId                0
# TransactionTime              0
# ItemCode                     0
# ItemDescription           2908
# NumberOfItemsPurchased       0
# CostPerItem                  0
# Country                      0
# dtype: int64

# %%
df = df.drop_duplicates() # Xóa giá trị trùng lặp
df=df[pd.notnull(df['UserId'])]
df=df[~(df['UserId']== -1)] # Xóa những data có id = -1

# %%
#Sau khi em qua sát thống kê thì thấy column 'NumberOfItemsPurchased' mang giá trị âm mặc dù nó là tổng số mặt hàng đã mua nên em se xư lí nó
df=df[~(df['NumberOfItemsPurchased'] < 0)]

# %%
df= df.drop('ItemDescription', axis =1) # Data này là mô tả thông tin nên không quan trọng => drop

# %%
UserID_count = df['UserId'].nunique() 
UserID_count
# Có tất cả 4334 người mua hàng
# Out:
# 4339

# %%
df['TransactionTime'] = pd.to_datetime(df['TransactionTime'])
df['TransactionTime_month'] = df['TransactionTime'].dt.strftime('%Y-%m')
# Out:
# /tmp/ipykernel_4304/1544533777.py:1: FutureWarning: Parsed string "Sat Feb 02 12:50:00 IST 2019" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df['TransactionTime'] = pd.to_datetime(df['TransactionTime'])

# %%
# Danh sách các column cần trực quan
list_visual = ['TransactionTime_month', 'NumberOfItemsPurchased', 'CostPerItem', 'Country']

# %%
for column in list_visual:
    plt.figure(figsize=(12, 8))
    sns.boxplot(x=df[column])
    plt.title(f'Histogram của cột {column}')
    plt.show()

# %%
# Lúc đầu em có dùng sns.boxplot để vẽ nhưng khi trực quan thì khá khó quan sát nên em trực quan thêm bằng histogram 
for column in list_visual:
    plt.figure(figsize=(16, 8))
    plt.hist(x=df[column], bins=40)
    plt.title(f'Histogram của cột {column}')
    plt.show()

# %%
# Em thấy giá trị '2028-02 vừa là giá trị của outlier chiếm tỉ lệ rất nhỏ và vừa không đúng thời gian giao  dịch (Thời gian cảu tương lai) nên em sẽ drop nó
df = df[~(df['TransactionTime'] == '2028-02')]

# %%
# Hàm để lọc outler bằng tứ phân vị
def remove_outliers(df, column):
    out=[]
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    out= df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return out

# %% [markdown]
# Khi nhìn váo boxplot và histogram thì em thấy 2 cột 'NumberOfItemsPurchased' và 'CostPerItem' điều có giá trị outlier lớn nhưng lại chiếm tỉ lệ nhỏ nên khi drop sẽ không ảnh hướng đến dữ liệu

# %%
outlier_NumberOfItemsPurchased= remove_outliers(df,'NumberOfItemsPurchased')
outlier_CostPerItem= remove_outliers(df,'CostPerItem')
# Em tạo 2 biến để tránh bị sao khi drop outlier của 1 cột thì data sẽ bị ảnh hưởng (loại outlier độc lâp)

# %%
df = df[~df['CostPerItem'].isin(outlier_CostPerItem['CostPerItem'])]
df = df[~df['NumberOfItemsPurchased'].isin(outlier_NumberOfItemsPurchased['NumberOfItemsPurchased'])]

# %% [markdown]
# ### 2. Calculate the number of Items purchased and prices in each month

# %%
NumberOfItemsPurchased_each_month = df['NumberOfItemsPurchased'].groupby(df['TransactionTime_month']).sum()
NumberOfItemsPurchased_each_month
# Out:
# TransactionTime_month
# 2018-02     385548
# 2018-03     255549
# 2018-04     391860
# 2018-05     463221
# 2018-06     530253
# 2018-07     520188
# 2018-08     509601
# 2018-09     491136
# 2018-10     599754
# 2018-11     615786
# 2018-12     992889
# 2019-01    1040100
# 2019-02     732282
# 2028-02      20295
# Name: NumberOfItemsPurchased, dtype: int64

# %%
df
# Out:
#          UserId  TransactionId     TransactionTime  ItemCode  \
# 1        337701        6283376 2018-12-26 09:06:00    482370
# 2        267099        6385599 2019-02-15 09:45:00    490728
# 3        380478        6044973 2018-06-22 07:14:00    459186
# 5        285957        6307136 2019-01-11 09:50:00   1787247
# 6        345954        6162981 2018-09-28 10:51:00    471576
# ...         ...            ...                 ...       ...
# 1077555  266805        6042476 2018-06-20 05:54:00    468951
# 1077599  304479        6335692 2019-01-25 09:01:00    484869
# 1077625  357084        6297599 2019-01-05 10:25:00    487263
# 1081271  374577        6277348 2018-12-23 10:34:00    478506
# 1081376  378861        5973099 2018-04-16 09:11:00    469707
#
#          NumberOfItemsPurchased  CostPerItem         Country  \
# 1                             3         3.52  United Kingdom
# 2                            72         0.90          France
# ...
